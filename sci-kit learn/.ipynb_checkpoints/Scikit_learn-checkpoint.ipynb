# %%
import numpy as np
import pandas as pd
import geopandas as gp
import rasterio
import matplotlib.pyplot as plt
from pyrsgis import raster

from skimage import io
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedShuffleSplit
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c9334bf6aeb6> in <module>
#       4 import rasterio
#       5 import matplotlib.pyplot as plt
# ----> 6 from pyrsgis import raster
#       7
#       8 from skimage import io
#
# ModuleNotFoundError: No module named 'pyrsgis'

# %%
#read path to dataset
#image
img_path = 'Opt_SAR_Stack.TIF'
#traing and test dataset
tp_src = gp.read_file('sgcplot.shp')
tp_crop = gp.read_file('croplabel.shp')
tp_ncrop = gp.read_file('noncroplabel.shp')

# read image
img = io.imread(img_path)
npimg = np.asarray(img)

# %%
imgplot = plt.imshow(npimg[2])

# %%
npdata = np.asarray(dataset)
print(type(npdata))
# Out:
# <class 'numpy.ndarray'>

# %%
dataset = rasterio.open(img_path)
print(dataset.count, dataset.width, dataset.height, dataset)
# Out:
# 20 2097 1718 <open DatasetReader name='Opt_SAR_Stack.TIF' mode='r'>

# %%
crop_label = tp_src.append(tp_crop)
crop_label.head(50)
# Out:
#     label                                           geometry
# 0       1  POLYGON Z ((34.32728 -0.78805 0.00000, 34.3272...
# 1       1  POLYGON Z ((34.33106 -0.78646 0.00000, 34.3312...
# 2       1  POLYGON Z ((34.33147 -0.78711 0.00000, 34.3312...
# 3       1  POLYGON Z ((34.33124 -0.78655 0.00000, 34.3313...
# 4       1  POLYGON Z ((34.32901 -0.79136 0.00000, 34.3292...
# 5       1  POLYGON Z ((34.32819 -0.79129 0.00000, 34.3282...
# 6       1  POLYGON Z ((34.32810 -0.79176 0.00000, 34.3281...
# 7       1  POLYGON Z ((34.32752 -0.79243 0.00000, 34.3276...
# 8       1  POLYGON Z ((34.32693 -0.79226 0.00000, 34.3269...
# 9       1  POLYGON Z ((34.32692 -0.79321 0.00000, 34.3268...
# 10      1  POLYGON Z ((34.32895 -0.79629 0.00000, 34.3289...
# 11      1  POLYGON Z ((34.32992 -0.79673 0.00000, 34.3297...
# 12      1  POLYGON Z ((34.33304 -0.79670 0.00000, 34.3329...
# 13      1  POLYGON Z ((34.33275 -0.79672 0.00000, 34.3327...
# 14      1  POLYGON Z ((34.33260 -0.79421 0.00000, 34.3325...
# 15      1  POLYGON Z ((34.33445 -0.79374 0.00000, 34.3342...
# 16      1  POLYGON Z ((34.33528 -0.79324 0.00000, 34.3352...
# 17      1  POLYGON Z ((34.33270 -0.79262 0.00000, 34.3326...
# 18      1  POLYGON Z ((34.33386 -0.79136 0.00000, 34.3345...
# 19      1  POLYGON Z ((34.33515 -0.79104 0.00000, 34.3357...
# 20      1  POLYGON Z ((34.33721 -0.79127 0.00000, 34.3372...
# 21      1  POLYGON Z ((34.33780 -0.79186 0.00000, 34.3378...
# 22      1  POLYGON Z ((34.33792 -0.79223 0.00000, 34.3382...
# 23      1  POLYGON Z ((34.33928 -0.79020 0.00000, 34.3389...
# 24      1  POLYGON Z ((34.34025 -0.79544 0.00000, 34.3401...
# 25      1  POLYGON Z ((34.33735 -0.79707 0.00000, 34.3373...
# 26      1  POLYGON Z ((34.33747 -0.79578 0.00000, 34.3375...
# 27      1  POLYGON Z ((34.33714 -0.79640 0.00000, 34.3371...
# 28      1  POLYGON Z ((34.33531 -0.79759 0.00000, 34.3352...
# 29      1  POLYGON Z ((34.34814 -0.79572 0.00000, 34.3484...
# 30      1  POLYGON Z ((34.34843 -0.79615 0.00000, 34.3487...
# 31      1  POLYGON Z ((34.34937 -0.79636 0.00000, 34.3495...
# 32      1  POLYGON Z ((34.34887 -0.79547 0.00000, 34.3492...
# 33      1  POLYGON Z ((34.35288 -0.79698 0.00000, 34.3529...
# 34      1  POLYGON Z ((34.35310 -0.79622 0.00000, 34.3531...
# 35      1  POLYGON Z ((34.34390 -0.79967 0.00000, 34.3442...
# 36      1  POLYGON Z ((34.34232 -0.80186 0.00000, 34.3426...
# 37      1  POLYGON Z ((34.34459 -0.80970 0.00000, 34.3443...
# 38      1  POLYGON Z ((34.34369 -0.81316 0.00000, 34.3434...
# 39      1  POLYGON Z ((34.34271 -0.81500 0.00000, 34.3426...
# 40      1  POLYGON Z ((34.34478 -0.81785 0.00000, 34.3444...
# 41      1  POLYGON Z ((34.35434 -0.81816 0.00000, 34.3551...
# 42      1  POLYGON Z ((34.35099 -0.82233 0.00000, 34.3509...
# 43      1  POLYGON Z ((34.33431 -0.81295 0.00000, 34.3342...
# 44      1  POLYGON Z ((34.32909 -0.80482 0.00000, 34.3289...
# 45      1  POLYGON Z ((34.32926 -0.80476 0.00000, 34.3292...
# 46      1  POLYGON Z ((34.31722 -0.79865 0.00000, 34.3172...
# 47      1  POLYGON Z ((34.31911 -0.79769 0.00000, 34.3190...
# 48      1  POLYGON Z ((34.31950 -0.79732 0.00000, 34.3193...
# 49      1  POLYGON Z ((34.31979 -0.79778 0.00000, 34.3196...
